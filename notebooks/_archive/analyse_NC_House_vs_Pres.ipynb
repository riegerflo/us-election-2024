# %% [markdown]
# https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2024_11_05/results_pct_20241105.zip

# %%
import pandas as pd

from us_election_2024.helpers import read_data, unique, filter_for, total_votes_per_precinct, filter_isin

# %%
df = read_data()
df
# Out:
#           County Election Date Precinct  Contest Group ID Contest Type  \
# 0       CALDWELL    11/05/2024        1              1155            S
# 1       CALDWELL    11/05/2024        1              1347            S
# 2       CALDWELL    11/05/2024        1              1393            S
# 3       CALDWELL    11/05/2024       10                 2            C
# 4       CALDWELL    11/05/2024       10                 4            C
# ...          ...           ...      ...               ...          ...
# 230487    WILKES    11/05/2024      104              1005            S
# 230488    WILKES    11/05/2024      104              1302            S
# 230489    WILKES    11/05/2024      104              1338            S
# 230490    WILKES    11/05/2024      104              1338            S
# 230491    WILKES    11/05/2024      104              1378            S
#
#                                              Contest Name  \
# 0             NC DISTRICT COURT JUDGE DISTRICT 36 SEAT 09
# 1                             NC STATE SENATE DISTRICT 45
# 2                                            US PRESIDENT
# 3                      CALDWELL COUNTY BOARD OF EDUCATION
# 4       CALDWELL SOIL AND WATER CONSERVATION DISTRICT ...
# ...                                                   ...
# 230487                                NC ATTORNEY GENERAL
# 230488                              NC SECRETARY OF STATE
# 230489                        NC STATE SENATE DISTRICT 36
# 230490                        NC STATE SENATE DISTRICT 36
# 230491                                       NC TREASURER
#
#                      Choice Choice Party  Vote For  Election Day  \
# 0       Richard S. Holloway          REP         1           580
# 1                  Kim Bost          DEM         1           173
# 2                Jill Stein          GRE         1             0
# 3           Michael Barrick          LIB         3           102
# 4              David Bruner                      1           158
# ...                     ...          ...       ...           ...
# 230487         Jeff Jackson          DEM         1            82
# 230488           Chad Brown          REP         1           260
# 230489        Darren Staley          DEM         1            85
# 230490         Eddie Settle          REP         1           270
# 230491          Brad Briner          REP         1           280
#
#         Early Voting  Absentee by Mail  Provisional  Total Votes  \
# 0                  0                 0            0          580
# 1                  0                 0            0          173
# 2                  0                 0            0            0
# 3                  0                 0            0          102
# 4                  0                 0            0          158
# ...              ...               ...          ...          ...
# 230487             0                 0            0           82
# 230488             0                 0            0          260
# 230489             0                 0            0           85
# 230490             0                 0            0          270
# 230491             0                 0            0          280
#
#        Real Precinct  Unnamed: 15
# 0                  Y          NaN
# 1                  Y          NaN
# 2                  Y          NaN
# 3                  Y          NaN
# 4                  Y          NaN
# ...              ...          ...
# 230487             Y          NaN
# 230488             Y          NaN
# 230489             Y          NaN
# 230490             Y          NaN
# 230491             Y          NaN
#
# [230492 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230492 entries, 0 to 230491
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   County            230492 non-null  object
#  1   Election Date     230492 non-null  object
#  2   Precinct          230492 non-null  object
#  3   Contest Group ID  230492 non-null  int64
#  4   Contest Type      230492 non-null  object
#  5   Contest Name      230492 non-null  object
#  6   Choice            230404 non-null  object
#  7   Choice Party      198337 non-null  object
#  8   Vote For          230492 non-null  int64
#  9   Election Day      230492 non-null  int64
#  10  Early Voting      230492 non-null  int64
#  11  Absentee by Mail  230492 non-null  int64
#  12  Provisional       230492 non-null  int64
#  13  Total Votes       230492 non-null  int64
#  14  Real Precinct     230492 non-null  object
#  15  Unnamed: 15       0 non-null       float64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 28.1+ MB

# %%
house_races = unique(df, "Contest Name", "US HOUSE")
house_races
# Out:
# ['US HOUSE OF REPRESENTATIVES DISTRICT 07',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 06',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 08',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 09',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 14',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 11',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 03',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 04',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 01',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 10',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 05',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 13',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 12',
#  'US HOUSE OF REPRESENTATIVES DISTRICT 02']

# %%
df_district = filter_for(df, "Contest Name", "US HOUSE OF REPRESENTATIVES DISTRICT 01")
df_district
# Out:
#            County Election Date Precinct  Contest Group ID Contest Type  \
# 959     EDGECOMBE    11/05/2024     0101              1379            S
# 979     EDGECOMBE    11/05/2024     0101              1379            S
# 1006    EDGECOMBE    11/05/2024     0501              1379            S
# 1011    EDGECOMBE    11/05/2024     0601              1379            S
# 1015    EDGECOMBE    11/05/2024     0801              1379            S
# ...           ...           ...      ...               ...          ...
# 230019     WILSON    11/05/2024     PRWK              1379            S
# 230099     WILSON    11/05/2024     PRTO              1379            S
# 230105     WILSON    11/05/2024     PRWC              1379            S
# 230257     WARREN    11/05/2024      008              1379            S
# 230267      WAYNE    11/05/2024       04              1379            S
#
#                                    Contest Name           Choice Choice Party  \
# 959     US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
# 979     US HOUSE OF REPRESENTATIVES DISTRICT 01        Don Davis          DEM
# 1006    US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
# 1011    US HOUSE OF REPRESENTATIVES DISTRICT 01        Don Davis          DEM
# 1015    US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
# ...                                         ...              ...          ...
# 230019  US HOUSE OF REPRESENTATIVES DISTRICT 01        Don Davis          DEM
# 230099  US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
# 230105  US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
# 230257  US HOUSE OF REPRESENTATIVES DISTRICT 01        Don Davis          DEM
# 230267  US HOUSE OF REPRESENTATIVES DISTRICT 01  Laurie Buckhout          REP
#
#         Vote For  Election Day  Early Voting  Absentee by Mail  Provisional  \
# 959            1            26             0                 0            0
# 979            1           222             0                 0            0
# 1006           1            75             0                 0            0
# 1011           1           153             0                 0            0
# 1015           1           162             0                 0            0
# ...          ...           ...           ...               ...          ...
# 230019         1            99           450                34            0
# 230099         1           298          1141                38            4
# 230105         1            24            91                 3            0
# 230257         1           197           468                25            2
# 230267         1           408          2054                50            2
#
#         Total Votes Real Precinct  Unnamed: 15
# 959              26             Y          NaN
# 979             222             Y          NaN
# 1006             75             Y          NaN
# 1011            153             Y          NaN
# 1015            162             Y          NaN
# ...             ...           ...          ...
# 230019          583             Y          NaN
# 230099         1481             Y          NaN
# 230105          118             Y          NaN
# 230257          692             Y          NaN
# 230267         2514             Y          NaN
#
# [978 rows x 16 columns]

# %%
district_precincts = df_district.Precinct.unique()
district_precincts
# Out:
# array(['0101', '0501', '0601', '0801', '5', 'K2', 'MH', 'C', 'K9', 'PH2',
#        'A1', 'P13A', 'P16A', 'P17A', 'PRWA', 'PRWB', 'PRWD', 'PRWJ',
#        'PRWQ', '003', '21', '008', '009', '013', 'ABSENTEE', '07', '08',
#        'CH', 'TRANSFER', 'K5', 'N', 'P21A', 'P22A', '04', '06', 'SH1',
#        'SH2', 'WH', 'IW', 'W2', 'C1', 'SOOX', 'PH1', 'W', 'WEL1-2',
#        'P05A', 'NEWTOW', 'RICH S', '0102', '0701', '1202', '1203',
#        'PROVISIONAL', '1', 'WM1', 'WM2', 'P07A', 'P18A', 'NH1', 'NV',
#        '11', '15', '22', '3', '4', 'EARLY VOTING 2', '1204', 'T1',
#        'EV-POW', 'M1', 'C2', 'EV CREECY GYM', 'EV CULTURE WELL CTN',
#        'GALATI', 'GAPL', 'LASKER', 'SEVERN', 'NORTH', 'PARKVI', 'P01A',
#        'P10A', 'P11A', 'P12A', 'P23A', '05', '12', '1001', '1101', 'PB',
#        'EAOX', '4N', 'SH', 'SW', 'CC', 'SCRK', 'NEW', 'SAL', 'NH', '1920',
#        'PRCR', 'PRSA', '002', '004', '005', '006', 'EARLY VOTING', '1201',
#        'M2', 'SN', 'K4', 'K6', 'FAUCT', 'RINGW', 'PRWM', 'PRWP', '0103',
#        'BUTWD', 'ENF1', 'A2', 'SK', 'RX', '6', 'WOEL',
#        'EV COOL SPRING CC', 'EARLY VOTING BOE', '2530', '17', '2', '0301',
#        'SH#1', 'RBV', 'NICANO', 'EAST H', 'PRWL', 'PRWR', 'LIT', 'RR3-4',
#        'RR7-9', '14', '03', 'PRWN', 'ARBA', 'BULL', 'CAST', 'CONC',
#        'EV RINGWOOD', 'EV HALIFAX', 'RR 11', 'BG', 'GRF', 'PRO', 'LAKE G',
#        'WOPO', 'EH1', '011', '012', '014', 'LM', '01', '13', '1205',
#        'HOL', 'P03A', 'P04A', 'P09A', 'EM', 'RR 10', 'CO', 'HV', 'ML',
#        'WN', 'CR', 'HMT', 'T2', 'V', 'WEST H', 'ANTI', 'BEAR', 'SHIN',
#        'WALS', 'I', 'K1', 'EV ROANOKE RAPIDS', 'HAL', 'SEABOA', '18',
#        'CRDL', 'SALM', '0401', '0901', '1301', 'EARLY VOTING 1', 'MIDD',
#        '16', '23', '28', 'SM', '4S', 'GSN', 'JMV', '001', 'P19A', 'P15A',
#        'BELVID', 'BETHEL', 'EV SCOTLAND NECK', 'EV-LW', 'EARLY VOTING 3',
#        'BR', 'CM', 'GASTON', 'PROL', 'PRTA', 'NIX', 'SOUTH', 'P24A',
#        'HPR', 'FC', 'K8', 'HTOP', 'P3', 'P2', 'P06A', 'P02A', 'P14A',
#        '27', '29', 'EV-LOB', 'CB', 'MAUR', 'SJ', 'UN', 'COMIPE', 'JARE',
#        'PRWH', 'PP', 'SUGG', 'WEL 3', 'A3', 'NEW HO', 'PRGA', '26',
#        'PRWE', '010', 'GW', 'WEST', 'PRBL', 'PRST', 'W1', 'IR', 'ENF 2',
#        'P20A', 'P1', '02', '09', '24', '10', '1401', 'HOOK', 'RR1-2',
#        'RRCE', 'SC', 'PRSP', 'WM', 'K3', 'K7', 'WD', '0104', '007',
#        '0201', 'PRTO', 'PRWI', 'P08A', 'KI', 'CREEKS', 'PRWC', 'KITT',
#        'PRWK', 'EAST'], dtype=object)

# %%
# df_pres = df[df.Precinct.isin(district_precincts) & (df["Contest Name"] == "US PRESIDENT")]
df_pres = filter_isin(df, "Precinct", district_precincts)
df_pres = filter_for(df_pres, "Contest Name", "US PRESIDENT")
df_pres
# Out:
#           County Election Date Precinct  Contest Group ID Contest Type  \
# 2       CALDWELL    11/05/2024        1              1393            S
# 97      CALDWELL    11/05/2024       11              1393            S
# 101     CALDWELL    11/05/2024       12              1393            S
# 110     CALDWELL    11/05/2024       15              1393            S
# 111     CALDWELL    11/05/2024       15              1393            S
# ...          ...           ...      ...               ...          ...
# 230447     WAYNE    11/05/2024       18              1393            S
# 230451     WAYNE    11/05/2024       21              1393            S
# 230465     WAYNE    11/05/2024       26              1393            S
# 230468     WAYNE    11/05/2024       27              1393            S
# 230474     WAYNE    11/05/2024       28              1393            S
#
#         Contest Name                    Choice Choice Party  Vote For  \
# 2       US PRESIDENT                Jill Stein          GRE         1
# 97      US PRESIDENT          Kamala D. Harris          DEM         1
# 101     US PRESIDENT  Write-In (Miscellaneous)          NaN         1
# 110     US PRESIDENT               Cornel West          JFA         1
# 111     US PRESIDENT  Write-In (Miscellaneous)          NaN         1
# ...              ...                       ...          ...       ...
# 230447  US PRESIDENT  Write-In (Miscellaneous)          NaN         1
# 230451  US PRESIDENT                Jill Stein          GRE         1
# 230465  US PRESIDENT               Cornel West          JFA         1
# 230468  US PRESIDENT           Donald J. Trump          REP         1
# 230474  US PRESIDENT           Donald J. Trump          REP         1
#
#         Election Day  Early Voting  Absentee by Mail  Provisional  \
# 2                  0             0                 0            0
# 97               109             0                 0            0
# 101                4             0                 0            0
# 110                1             0                 0            0
# 111                0             0                 0            0
# ...              ...           ...               ...          ...
# 230447             0             2                 0            0
# 230451             1             5                 0            0
# 230465             1             1                 0            0
# 230468            66           223                13            1
# 230474           294          1061                29           18
#
#         Total Votes Real Precinct  Unnamed: 15
# 2                 0             Y          NaN
# 97              109             Y          NaN
# 101               4             Y          NaN
# 110               1             Y          NaN
# 111               0             Y          NaN
# ...             ...           ...          ...
# 230447            2             Y          NaN
# 230451            6             Y          NaN
# 230465            2             Y          NaN
# 230468          303             Y          NaN
# 230474         1402             Y          NaN
#
# [6018 rows x 16 columns]

# %%
len(df_pres.Precinct.unique())
# Out:
# 279

# %%
len(district_precincts)
# Out:
# 279

# %%
total_votes_per_precinct(df_district)
# Out:
#           Early Voting  Total Votes
# Precinct
# 001                598          928
# 002                515          742
# 003                443          706
# 004                387          592
# 005                614          879
# ...                ...          ...
# WM1                  0          397
# WM2                  0          437
# WN                 661          856
# WOEL                 1            1
# WOPO                 0          166
#
# [279 rows x 2 columns]

# %%
total_votes_per_precinct(df_pres)
# Out:
#           Early Voting  Total Votes
# Precinct
# 001               1953         2737
# 002               3245         4241
# 003               1946         2798
# 004               1969         2805
# 005               1261         1840
# ...                ...          ...
# WM1                  0          403
# WM2                  0          442
# WN                 675          879
# WOEL               917         1128
# WOPO                 0          167
#
# [279 rows x 2 columns]
